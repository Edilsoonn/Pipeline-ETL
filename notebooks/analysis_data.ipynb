# %%
path = '../data/weather_data.json'
import pandas as pd
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                                                      weather  \
# 0  [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]
#
#        base  visibility          dt  timezone       id       name  cod  \
# 0  stations       10000  1787436643    -10800  3448439  São Paulo  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -46.6361   -23.5475      16.04            15.81          14.69
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0          17.25           1021             81            1021
#
#    main.grnd_level  wind.speed  wind.deg  wind.gust  clouds.all  sys.type  \
# 0              930        4.02       140       4.02           5         2
#
#     sys.id sys.country  sys.sunrise  sys.sunset
# 0  2082654          BR   1787390806  1787431952
